# %%
x = 5
y = 2

# %%
x < y
# Out:
# False

# %%
x > y
# Out:
# True

# %%
y = 5

# %%
x <= y
# Out:
# True

# %%
x <= 5.0
# Out:
# True

# %%
x = 10
y = 8

# %%
x = y

# %%
x
# Out:
# 8

# %%
x == y
# Out:
# True

# %%
x != y
# Out:
# False

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
2 > 1 or 3 < 2
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
5 in [10,20,30]
# Out:
# False

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True

# %%
my_superhero = "thor"

# %%
my_superhero == "thor"
# Out:
# True

# %%
my_superhero == "batman"
# Out:
# False

# %%
if my_superhero == "thor":
    #indentation
    print("my superhero is thor")
# Out:
# my superhero is thor

# %%
if my_superhero == "batman":
    #indentation
    print("my superhero is thor")

# %%
if my_superhero == "batman":
    #indentation
    print("my superhero is thor")
#--#
print("hello")
# Out:
# hello

# %%
if my_superhero == "thor":
    #indentation
    print("my superhero is thor")
#--#
print("hello")
# Out:
# my superhero is thor
# hello

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero:  thor

# %%
if my_superhero == "superman":
    print("superman")
elif my_superhero == "batman":
    print("batman")
elif my_superhero == "thor":
    print("thor")
else:
    print(":(")
# Out:
# thor

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero:  spider man

# %%
my_superhero_list = ["spider man","iron man","thor","black widow"]

# %%
if my_superhero in my_superhero_list:
    print(":))")
else:
    print(":((")
# Out:
# :))
