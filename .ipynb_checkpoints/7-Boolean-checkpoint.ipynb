# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
5 < 3
# Out:
# False

# %%
3 == 4
# Out:
# False

# %%
age = input("Enter your age")
int(age) < 18
# Out:
# Enter your age 5
# True
