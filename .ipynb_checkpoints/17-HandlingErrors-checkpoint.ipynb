# %%
age = input("enter age: ")
# Out:
# enter age:  50

# %%
age
# Out:
# '50'

# %%
int(age) * 2
# Out:
# 100

# %%
# try - except

# %%
while True:
    try:
        myAge = int(input("enter age: "))
        print(myAge * 2)
        break
    except:
        print("enter your age!!")
    else:
        print("else executed")
    finally:
        print("finally")
# Out:
# enter age:  rojin
# enter your age!!
# finally
# enter age:  rojin
# enter your age!!
# finally
# enter age:  23
# 46
# finally
