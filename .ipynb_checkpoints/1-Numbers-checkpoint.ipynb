# %%
2 + 4
# Out:
# 6

# %%
2 * 4
# Out:
# 8

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
10 - 100
# Out:
# -90

# %%
age = 50

# %%
age
# Out:
# 50

# %%
age / 2
# Out:
# 25.0

# %%
type(age)
# Out:
# int

# %%
type(age / 2)
# Out:
# float

# %%
#float -> floating point

# %%
x = -100

# %%
type(x)
# Out:
# int

# %%
pi = 3.14

# %%
x + pi
# Out:
# -96.86

# %%
x = 10

# %%
x = 20

# %%
x + 10
# Out:
# 30

# %%
myFloat = 1.34432423

# %%
type(myFloat)
# Out:
# float

# %%
#camelCase
#snake_case

# %%
5.4 - 2
# Out:
# 3.4000000000000004

# %%
type(5.4 - 2)
# Out:
# float

# %%
4.2 *3 - 10
# Out:
# 2.6000000000000014

# %%
2 - 10 * 2
# Out:
# -18

# %%
2 ** 3
# Out:
# 8

# %%
10 % 3 #remainder
# Out:
# 1
