# %%
myString = "hello world"

# %%
myString.split()
# Out:
# ['hello', 'world']

# %%
type(myString.split())
# Out:
# list

# %%
#list

# %%
myString[0]
# Out:
# 'h'

# %%
#myString[0] = "a"
#immutable - immutability

# %%
myString = "rojin"

# %% [markdown]
# # List

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100

# %%
#mutable, mutability

# %%
myList
# Out:
# [100, 20, 30]

# %%
len(myList)
# Out:
# 3

# %%
myList[-1]
# Out:
# 30

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 80]

# %%
myList.count(100)
# Out:
# 1

# %%
myList.index(20)
# Out:
# 1

# %%
myList.insert(2,35) #2. indekse 35 elemanını ekle

# %%
myList
# Out:
# [100, 20, 35, 35, 30, 80]

# %%
myList.pop()
# Out:
# 80

# %%
myList
# Out:
# [100, 20, 35, 35, 30]

# %%
myList.remove(20)

# %%
myList
# Out:
# [100, 35, 35, 30]

# %%
myList.reverse()

# %%
myList
# Out:
# [30, 35, 35, 100]

# %%
myList.sort()

# %%
myList
# Out:
# [30, 35, 35, 100]

# %%
x = input("enter x:")
# Out:
# enter x: 10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y:")
# Out:
# enter y: 20

# %%
y
# Out:
# '20'

# %%
z = input("enter z:")
# Out:
# enter z: 30

# %%
z
# Out:
# '30'

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
inputList
# Out:
# []

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1]) * 2
# Out:
# 40

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
mixedList = ["rojin",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
type(mixedList[0])
# Out:
# str

# %%
#nestedList

# %%
myNestedList = [10,20,3.14,"rojin",[1,2,3]]

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
myNestedList[4][1]
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2]
# Out:
# ['c', 'd', 'e']

# %%
lastList[2][1]
# Out:
# 'd'

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
