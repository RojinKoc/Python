# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
#myTuple[0] = 100

# %%
#immutability

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("a")
# Out:
# 1

# %%
resultTuple = (10,200,20)

# %%
resultTuple
# Out:
# (10, 200, 20)

# %%
resultList = list(resultTuple)

# %%
resultList
# Out:
# [10, 200, 20]
